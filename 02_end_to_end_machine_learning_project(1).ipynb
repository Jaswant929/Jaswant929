# %% [markdown]
# In this file, Compare the accuracy of your KNN classifier with the classifiers you fine-tuned in Lab 4, such as SGD and Random Forest Classifiers.

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml2/blob/master/02_end_to_end_machine_learning_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml2/blob/master/02_end_to_end_machine_learning_project.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# # Setup

# %% [markdown]
# # Fine-Tune Your Model

# %% [markdown]
# ## Grid Search

# %%
from sklearn.metrics import accuracy_score

# Assuming the classifiers are already trained and fine-tuned (best_knn, sgd_clf, rf_clf):
# Predict on the test set using each classifier

# KNN
y_pred_knn = best_knn.predict(X_test_scaled)
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print(f"KNN Classifier Test Accuracy: {accuracy_knn:.4f}")

# SGD
y_pred_sgd = sgd_clf.predict(X_test_scaled)
accuracy_sgd = accuracy_score(y_test, y_pred_sgd)
print(f"SGD Classifier Test Accuracy: {accuracy_sgd:.4f}")

# Random Forest
y_pred_rf = rf_clf.predict(X_test_scaled)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Random Forest Classifier Test Accuracy: {accuracy_rf:.4f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# KNN Classifier Test Accuracy: 0.1143
# SGD Classifier Test Accuracy: 0.9018
# Random Forest Classifier Test Accuracy: 0.9674

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of classifier names and their corresponding accuracies
classifiers = ['KNN', 'SGD', 'Random Forest']
accuracies = [accuracy_knn, accuracy_sgd, accuracy_rf]

# Plot the accuracies
plt.figure(figsize=(10, 6))
sns.barplot(x=classifiers, y=accuracies, palette='coolwarm')
plt.title("Classifier Accuracy Comparison")
plt.xlabel("Classifier")
plt.ylabel("Accuracy")
plt.ylim(0.90, 1.0)  # Limit y-axis to better visualize differences
plt.grid(True)
plt.show()
# Out:
# <ipython-input-32-4d2ba9b1162a>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=classifiers, y=accuracies, palette='coolwarm')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
from sklearn.metrics import confusion_matrix

# Function to plot a confusion matrix
def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
    plt.title(f"Confusion Matrix for {title}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

# Plot confusion matrices for KNN, SGD, and Random Forest classifiers
plot_confusion_matrix(y_test, y_pred_knn, "KNN Classifier")
plot_confusion_matrix(y_test, y_pred_sgd, "SGD Classifier")
plot_confusion_matrix(y_test, y_pred_rf, "Random Forest Classifier")

# %%
from sklearn.metrics import classification_report

# Print classification reports for all classifiers
print("KNN Classifier Report:")
print(classification_report(y_test, y_pred_knn))

print("SGD Classifier Report:")
print(classification_report(y_test, y_pred_sgd))

print("Random Forest Classifier Report:")
print(classification_report(y_test, y_pred_rf))
# Out:
# KNN Classifier Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1343
#            1       0.11      1.00      0.21      1600
#            2       0.00      0.00      0.00      1380
#            3       0.00      0.00      0.00      1433
#            4       0.00      0.00      0.00      1295
#            5       0.00      0.00      0.00      1273
#            6       0.00      0.00      0.00      1396
#            7       0.00      0.00      0.00      1503
#            8       0.00      0.00      0.00      1357
#            9       0.00      0.00      0.00      1420
#
#     accuracy                           0.11     14000
#    macro avg       0.01      0.10      0.02     14000
# weighted avg       0.01      0.11      0.02     14000
#
# SGD Classifier Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97      1343
# ...

# %%
from sklearn.metrics import precision_recall_fscore_support

# Get metrics for each classifier
knn_metrics = precision_recall_fscore_support(y_test, y_pred_knn, average='weighted')
sgd_metrics = precision_recall_fscore_support(y_test, y_pred_sgd, average='weighted')
rf_metrics = precision_recall_fscore_support(y_test, y_pred_rf, average='weighted')

# Plot the metrics
labels = ['Precision', 'Recall', 'F1-Score']
x = np.arange(len(labels))

# Create the bar plots for each classifier
width = 0.2  # Bar width
plt.figure(figsize=(10, 6))
plt.bar(x - width, knn_metrics[:-1], width, label='KNN')
plt.bar(x, sgd_metrics[:-1], width, label='SGD')
plt.bar(x + width, rf_metrics[:-1], width, label='Random Forest')

# Add labels, title, and formatting
plt.title("Comparison of Precision, Recall, and F1-Score")
plt.xticks(x, labels)
plt.xlabel("Metrics")
plt.ylabel("Score")
plt.legend(loc="best")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Randomized Search
